# %% [markdown]
# # Question 1

# %%
"""
Task1. String Normalizer & Finder. Write a function normalize_and_find(text:
str, needle: str) -> int that: (1) trims whitespace on both ends, (2) converts to lowercase, then (3) returns the index of the first occurrence of needle using
a safe search (return −1 if not found). Discuss alternatives (find vs. index), and how your choice affects error handling. Anchor concepts: stripping, case conversion,
find/replace, string immutability. Reference: :contentReference[oaicite:6]index=6

Chatgpt(prompt): String Normalizer & Finder. Write a function normalize_and_find(text:
str, needle: str) -> int that: (1) trims whitespace on both ends, (2) converts to lowercase, then (3) returns the index of the first occurrence of needle using
a safe search (return −1 if not found). Discuss alternatives (find vs. index), and how your choice affects error handling. Anchor concepts: stripping, case conversion,
find/replace, string immutability. Reference: :contentReference[oaicite:6]index=6 explain this question to me.

#Chatgpt answer:
Great question 👍

In **Python**, the **syntax of a function** (the way you write or define it) follows this basic pattern:
---
### 🧩 **Function Syntax**
```python
def function_name(parameters):
    # function body (code to execute)
    return value
```
---
### 🧠 **Parts Explained**
| Part            | Description                                                     |
| --------------- | --------------------------------------------------------------- |
| `def`           | Keyword that tells Python you’re defining a function.           |
| `function_name` | The name you give your function (should describe what it does). |
| `(parameters)`  | Values that the function can receive as input (optional).       |
| `:`             | Colon indicates the start of the function body.                 |
| Indented code   | The set of statements that the function will execute.           |
| `return`        | (Optional) Sends a value back to the caller.                    |
---
### 🧮 **Example**
```python
def greet(name):
    message = "Hello, " + name + "!"
    return message
```
**How to use it:**
```python
print(greet("Lourdyn"))
```
**Output:**
```
Hello, Lourdyn!
```
---
### 🧱 **Function Without Parameters**

```python
def say_hello():
    print("Hello there!")
```
Call it with:
```python
say_hello()
```
---
### 🧰 **Function With Multiple Parameters**
```python
def add_numbers(a, b):
    return a + b
```
Call it with:
```python
result = add_numbers(3, 5)
print(result)
```
Output:
```
8
```
---
So in your earlier question, the function
```python
def normalize_and_find(text: str, needle: str) -> int:
```
follows the same syntax — it just **adds type hints**:
* `text: str` → means the parameter `text` should be a string.
* `needle: str` → means the parameter `needle` should also be a string.
* `-> int` → means the function will return an integer value.
---
Would you like me to explain **type hints** (`: str`, `-> int`) more clearly next?

Critique:

Correctness:
The explanation is accurate.It clearly shows what the question expected output and how the function works using .strip(), .lower(), and .find()
Complexity:
The function runs efficiently since it only goes through the text once.
Robustness:
It works for most inputs and handles things safely with .find().
Readability:
The explanation is clear, easy to read, and well-organized. The examples and step-by-step parts make it simple to understand. 
Faithfulness:
It follows the first topic we discussed about .strip() and .lower(), which Sir Umpad thought us. Reference: Lesson 1.

Improved code:
"""
def Normalize_and_find(text, needle):
    text = text.strip()
    text = text.lower()
    needle = needle.lower()
    needle = text.find(needle)
    return needle
string1 = input("Input any text: ")
string2 = input("Enter a word to search: ")
print(Normalize_and_find(string1,string2))
"""
Discussion:
The function can use find() or index() to locate a substring. find() is safer since it returns -1 if not found, while index() raises an error. 
Using find() keeps the code simple and avoids exceptions. Methods like .strip() and .lower() create new strings because strings are immutable, 
making the function efficient and safe.
"""
# Out:
# Input any text:  Lourdyn Neil Verdida
# Enter a word to search:  Neil
# 8
# '\nThe function can use find() or index() to locate a substring. find() is safer since it returns -1 if not found, while index() raises an error. \nUsing find() keeps the code simple and avoids exceptions. Methods like .strip() and .lower() create new strings because strings are immutable, \nmaking the function efficient and safe.\n'

# %% [markdown]
# # Question 2

# %%
"""
Task2: Leetspeak Translator (Parametric). Generalize our leetspeak idea: write translate(text:
str, mapping: dict[str,str]) -> str that applies a mapping (e.g., {’a’:’4’,’e’:’3’,...}) over lowercase letters only, leaving others unchanged. 
Explain why strings are immutable and show an efficient approach (e.g., list join vs. repeated concatenation). Anchor concepts: replace, 
iteration strategies, efficiency. Reference: :contentReference[oaicite:7]index=7

Chatgpt prompt: Leetspeak Translator (Parametric). Generalize our leetspeak idea: write translate(text: str, mapping: dict[str,str]) -> str that applies a mapping 
(e.g., {’a’:’4’,’e’:’3’,...}) over lowercase letters only, leaving others unchanged. Explain why strings are immutable and show an efficient approach (e.g., list join vs. repeated concatenation). 
Anchor concepts: replace, iteration strategies, efficiency. Reference: :contentReference[oaicite:7]index=7 explain this question to me and what is the expected output

Alright — let’s break this question down in **simple terms** 👇
---
### 💡 What the question is asking
You need to **create a function** called `translate(text, mapping)` that turns **normal text into leetspeak** (a style where letters are replaced by symbols or numbers).
Example of **leetspeak mapping**:
```python
mapping = {'a': '4', 'e': '3', 'i': '1', 'o': '0', 's': '5'}
```
So the word `"hello"` would turn into `"h3ll0"`.
---
### 🧠 What the function should do
Your function:
```python
def translate(text: str, mapping: dict[str, str]) -> str:
```
should:
1. **Go through each letter** in `text`.
2. **Check if it’s a lowercase letter** found in the `mapping` dictionary.
   * If yes → replace it with the mapped value.
   * If not → keep it the same.
3. **Return** the new translated string.
---
### ⚙️ Example
```python
mapping = {'a': '4', 'e': '3', 'i': '1', 'o': '0', 's': '5'}
print(translate("easy", mapping))
```
✅ **Expected output:**
```
34sy
```
Explanation:
* `e → 3`
* `a → 4`
* `s → s` (if not in lowercase or not mapped, it stays)
* `y → y` (unchanged)
---
### 🧩 Important concept: **String immutability**
In Python, **strings cannot be changed once created** — this means you can’t directly edit a character inside a string.
That’s why if you try:
```python
text[0] = 'x'
```
it will cause an error.
So when we "replace" letters, we’re actually **building a new string**.
---
### ⚡ Efficient way to do it
Instead of adding characters one by one (like `result += new_char`),
which is **slow** because Python makes a new string each time,
we use a **list + join** approach:
```python
def translate(text, mapping):
    result = []
    for ch in text:
        if ch in mapping:
            result.append(mapping[ch])
        else:
            result.append(ch)
    return ''.join(result)
```
This is **faster and more memory-efficient**.
---
### 🧾 Anchor Concepts Mentioned:
* **replace** → swapping characters
* **iteration strategies** → using a loop to go through each character
* **efficiency** → using `list` + `join` instead of repeated string concatenation
---
### ✅ Summary:
You’re asked to:
1. Make a leetspeak translator using a mapping dictionary.
2. Only replace lowercase letters.
3. Explain that strings are immutable, so you use a list and `"".join()` to build the final result efficiently.
4. The expected output is a new “leet” version of the input text.
Would you like me to show you the **complete working code** for this function too?

Critique:

Correctness: Explains leetspeak conversion accurately and shows expected behavior clearly ("easy" → "34sy"). The logic for character replacement matches the mapping dictionary and correctly handles unmapped characters by leaving them unchanged.
Complexity: Runs in O(n) time and O(1) extra space since each character is checked once. The use of a list and "".join()" makes it efficient and avoids repeated string concatenation.
Robustness: Works correctly for both mapped and unmapped characters. Could improve by handling uppercase letters or adding input validation.
Readability: Well-structured and easy to follow. Clear examples and explanations make the logic understandable. Minor improvement: add a brief docstring or inline comments for clarity.
Faithfulness: Uses string iteration, replacement, and immutability concepts consistent with our lecture notes on efficient string handling. Reference:Lesson 5


Improved code:
"""
def translate(text,mapping):
    result = " "
    for ch in text:
        if ch in mapping:
            result += mapping[ch]
        else:
            result += ch
    return result
string1 = input("Input Your Name: ")
mapping = {'a': '4', 'e': '3', 'i': '1', 'o': '0', 's': '5'}
print(translate(string1,mapping))
"""
Discussion:
Strings are immutable because once created, their data cannot be changed in memory. This ensures data safety, consistency, and efficiency. 
To build strings efficiently, use ' '.join(list) instead of repeated concatenation, since joining lists avoids creating multiple temporary 
strings during iteration.
"""
# Out:
# Input Your Name:  asdrwds
#  45drwd5
# "\nStrings are immutable because once created, their data cannot be changed in memory. This ensures data safety, consistency, and efficiency. \nTo build strings efficiently, use ' '.join(list) instead of repeated concatenation, since joining lists avoids creating multiple temporary \nstrings during iteration.\n"

# %% [markdown]
# # Question 3

# %%
"""
Task:  Currency Formatter & Rounding Ties-to-Even. Write fmt_money(x: float)-> str that returns a string like 1,234.50 using proper rounding (banker’s round
ing / ties-to-even). Include test cases that demonstrate ties (e.g., 2.5, 3.5). Explain2 floating-point representation error and how formatting mitigates it for display. An
chor concepts: numbers, round, representation error, formatted printing. Reference: :contentReference[oaicite:8]index=8

Chatgpt Prompt: Currency Formatter & Rounding Ties-to-Even. Write fmt_money(x: float)-> str that returns a string like 1,234.50 using proper rounding (banker’s round ing / ties-to-even). 
Include test cases that demonstrate ties (e.g., 2.5, 3.5). explain this part to me

Chatgpt Answer:
Sure! Let’s break that down simply 👇
---
### 💡 **Goal**
You need to write a Python function:
```python
def fmt_money(x: float) -> str:
```
This function will take a number (like `1234.5`) and return a **formatted money string** like this:
```
"1,234.50"
```
It must include:
* **Commas** for thousands
* **Two decimal places**
* **Banker’s rounding (ties-to-even)**
---
### 💰 **What is banker’s rounding (ties-to-even)?**
When a number ends exactly halfway between two choices — for example, `2.5` (between `2` and `3`) — Python’s default rounding rule is **ties-to-even**.
That means:
* `2.5` → **2** (because 2 is even)
* `3.5` → **4** (because 4 is even)
So it “rounds to the nearest even number” to prevent rounding bias in financial calculations.
You can test this easily:
```python
print(round(2.5))  # 2
print(round(3.5))  # 4
```
---
### 🧮 **Formatting for currency**
You can use Python’s format specifier for commas and two decimals:
```python
f"{x:,.2f}"
```
This means:
* `,` → adds commas
* `.2f` → keeps two digits after the decimal
---
### ✅ **Putting it together**
Here’s a simple implementation:
```python
def fmt_money(x: float) -> str:
    return f"{round(x, 2):,.2f}"
```
---
### 🧪 **Test cases**
```python
print(fmt_money(1234.5))     # 1,234.50
print(fmt_money(2.5))        # 2.00  (ties to even)
print(fmt_money(3.5))        # 4.00  (ties to even)
print(fmt_money(1234567.899))# 1,234,567.90
```
---
So in short:
> **Banker’s rounding** avoids bias by rounding .5 to the nearest *even* number, and **`f"{x:,.2f}"`** ensures proper money formatting.
Critique:
Correctness: The explanation clearly describes how the function works using rounding rules and formatting.
Complexity: The function runs in O(1) time and space since formatting and rounding are constant-time operations.
Robustness: It works well for most numeric inputs. Adding error handling for invalid or non-numeric input could make it more reliable.
Readability: The code and explanation are clean, short, and easy to understand. A short docstring could improve clarity.
Faithfulness: It follows the Python Programming II lesson on rounding and number formatting using f-strings. Reference: Lesson 2 — Rounding Numbers.
Improved code:
"""
def fmt_money(x):
    return f"{x:,.2f}"
num1 = input("Input a float: ")
num1 = float(num1)
print(fmt_money(num1))
"""
Discussion: 
Floating-point representation error happens because computers store decimal numbers in binary, and some values like 0.1 or 0.2 cannot be represented exactly. 
This leads to small inaccuracies such as 0.1 + 0.2 = 0.30000000000000004. Using functions like round() or formatting methods such as f"{x:.2f}" reduces these 
errors when displaying numbers by limiting decimal places and showing a clean, readable value. Reference: Lesson 2
"""
# Out:
# Input a float:  51235.21643
# 51,235.22

# %% [markdown]
# # Question 4

# %%
"""
Task4:  Exponent Tool & Input Validation. Create a CLI program exponent.py that
 reads two values, validates they are numeric, handles errors gracefully (e.g., ValueError),
 and prints a ** b with clear messages. Compare using try/except vs. pre-validation
 with str.isdigit() (and why isdigit() is insufficient for negatives/floats). An
chor concepts: arithmetic operators, exceptions, input. Reference: :contentRefer
ence[oaicite:9]index=9, :contentReference[oaicite:10]index=10

Chatgpt prompt: Exponent Tool & Input Validation. Create a CLI program exponent.py that reads two values, 
validates they are numeric, handles errors gracefully (e.g., ValueError), and prints a ** b with clear messages. 
explain this to me

Chatgpt Answer:
Sure! Let’s break this down simply 👇
---
### 💡 **Goal**
You need to make a **command-line program** (`exponent.py`) that:
1. Asks the user for **two values** — a base and an exponent.
2. **Checks** if both inputs are valid numbers.
3. If valid, **computes `a ** b`** (a raised to the power of b).
4. If not valid, shows a **friendly error message** instead of crashing.
---
### 🧠 **Step-by-step explanation**
#### 1. **Read user input**
You’ll use `input()` to get values from the user:
```python
a = input("Enter the base: ")
b = input("Enter the exponent: ")
```
---
#### 2. **Validate input**
Before doing math, you must ensure the inputs are **numbers** (not text like “hello”).
You can do this by trying to convert them to `float`.
If conversion fails, Python raises a `ValueError`, so we’ll handle that safely.
---
#### 3. **Handle errors gracefully**
Use a `try-except` block to catch errors:
```python
try:
    a = float(a)
    b = float(b)
except ValueError:
    print("Error: Please enter valid numeric values.")
    exit()
```
This stops the program with a clear message instead of a traceback.
---
#### 4. **Compute the exponent**
If both are valid, calculate:
```python
result = a ** b
print(f"{a} raised to the power of {b} is {result}")
```
---
### ✅ **Complete working example**
```python
# exponent.py
try:
    a = float(input("Enter the base: "))
    b = float(input("Enter the exponent: "))
    result = a ** b
    print(f"{a} raised to the power of {b} is {result}")
except ValueError:
    print("Error: Please enter valid numeric values.")
```
---
### 🧪 **Example runs**
**Valid input:**
```
Enter the base: 2
Enter the exponent: 3
2.0 raised to the power of 3.0 is 8.0
```
**Invalid input:**
```
Enter the base: two
Enter the exponent: 3
Error: Please enter valid numeric values.
```
---
### 📝 **Key ideas**
* `try` and `except` prevent program crashes.
* `float()` helps accept both integers and decimals.
* `a ** b` performs exponentiation.
* The program gives **clear, friendly output** for both success and error cases.
Critique
Correctness: The explanation is accurate and aligns with the expected logic of reading inputs, validating data, and computing exponents. 
Complexity: The program runs in O(1) time and space since it performs only basic arithmetic and input operations.
Robustness: The code safely handles invalid inputs and prevents crashes using exception handling.
Readability: The structure is clear, well-commented, and easy to follow. Variable names and print statements make the flow understandable to me.
Faithfulness: It follows the structure and concepts from Python Programming Lesson 2, especially in using input(), float().

Improved Code: 
"""
import exponent as expo
prompt = float(input("Enter a Base:" ))
asd = expo.cube(prompt)
print(f"The Cuberoot of {prompt} is equal to {asd:.2f}")
"""
Discussion: 
try/except is better than str.isdigit() because it works for any number, including negatives (-5) and floats (3.14).
isdigit() only returns True for whole positive numbers with digits only. Using try/except with float() 
handles all valid numeric input and prevents errors safely, which makes it more reliable for arithmetic operations and user input validation.
Reference: Lesson 2 Arithmetic Operators.
"""
# Out:
# Enter a Base: 24.1
# The Cuberoot of 24.1 is equal to 13997.52

# %% [markdown]
# # Question 5

# %%
"""
Task5:  Password Policy Checker (If/Elif/Else + Loops). Implementcheck_password(pw:
 str)-> dict that validates: length ≥ 10, at least one uppercase, one lowercase,
 one digit, one symbol in !@#$%^&*, and no spaces. Return a dict of booleans per
 rule and an overall pass/fail. Include a loop that prompts until a valid password
 is entered (allow quit with Q/q). Anchor concepts: conditionals, logical operators,
 loops, break/continue. Reference: :contentReference[oaicite:11]index=11

Chatgpt Prompt: str)-> dict that validates: length ≥ 10, at least one uppercase, one lowercase,
 one digit, one symbol in !@#$%^&*, and no spaces. Return a dict of booleans per
 rule and an overall pass/fail. Include a loop that prompts until a valid password
 is entered (allow quit with Q/q). Explain this to me

Chatgpt Answer: Perfect — this one’s about **building a password validation system** that checks multiple rules and keeps asking the user until they enter a valid password (or quit). Let’s go step by step 👇
---

### 💡 **Goal**

You’ll write a function called:

```python
def check_password(pw: str) -> dict:
```

It checks several **rules** about the password and returns whether each rule passed or failed, plus an overall result.

---

### 🧩 **Rules to validate**

1. **Length ≥ 10** characters
2. **At least one uppercase** letter (`A–Z`)
3. **At least one lowercase** letter (`a–z`)
4. **At least one digit** (`0–9`)
5. **At least one special symbol** in `!@#$%^&*`
6. **No spaces** allowed

---

### ⚙️ **Return format**

The function should return a **dictionary** showing each check as `True` or `False`, and a final `"pass"` result.

Example:

```python
{
  "length": True,
  "uppercase": True,
  "lowercase": True,
  "digit": False,
  "symbol": True,
  "no_space": True,
  "pass": False
}
```

Here, `"pass": False` because not all rules passed.

---

### 🧠 **How to implement it**

You’ll use **string methods** and **any()** for checking:

```python
def check_password(pw: str) -> dict:
    rules = {
        "length": len(pw) >= 10,
        "uppercase": any(c.isupper() for c in pw),
        "lowercase": any(c.islower() for c in pw),
        "digit": any(c.isdigit() for c in pw),
        "symbol": any(c in "!@#$%^&*" for c in pw),
        "no_space": " " not in pw
    }
    rules["pass"] = all(rules.values())  # True only if all rules are True
    return rules
```

---

### 🔁 **Loop until valid or quit**

You’ll prompt the user repeatedly until the password passes all checks or they press `Q` or `q` to quit.

```python
while True:
    pw = input("Enter password (or Q to quit): ")
    if pw.lower() == "q":
        print("Goodbye!")
        break

    result = check_password(pw)
    if result["pass"]:
        print("✅ Password is valid!")
        break
    else:
        print("❌ Invalid password. Here’s what failed:")
        for rule, passed in result.items():
            if rule != "pass" and not passed:
                print(f" - {rule} failed")
```

---

### 🧪 **Example runs**

**Input:**

```
Enter password (or Q to quit): Hello123
```

**Output:**

```
❌ Invalid password. Here’s what failed:
 - length failed
 - symbol failed
```

**Input:**

```
Enter password (or Q to quit): Hello@12345
```

**Output:**

```
✅ Password is valid!
```

---

### 🧾 **Summary**

* **`check_password()`** validates each rule using string checks.
* **Returns a dictionary** of boolean results.
* **Loop keeps prompting** until the password is valid or the user quits.
* Uses **`any()`**, **`.isupper()`**, **`.islower()`**, **`.isdigit()`**, and **membership tests (`in`)** — all consistent with your notes on string methods and iteration.

Critique
Correctness: Logic matches the spec: all six rules are checked and "pass" is True only if all pass. The loop stops on valid password or q.
Complexity: One pass over the string per check set → O(n) time, O(1) space. Good for interactive use.
Robustness: Handles spaces and missing classes well. Could add: mask input (no echo), retry count, and messages that map rule keys to friendlier text.
Readability: Code is clear. Minor tweaks: rename keys to user-friendly labels, add a short docstring, and keep print formatting consistent.
Faithfulness: Uses the taught string methods (any(), .isupper(), .islower(), .isdigit(), membership in) and a simple input loop, matching our lessons.

Impoved Code: 

"""
def check_password(pw):
    if len(pw) < 10:
        print("Atleast 10 characters")
        return
    if pw.isupper():
        print("Include Lower case")
        return
    elif pw.islower():
        print("Include Upper case")
        return
    elif not any(c.isdigit() for c in pw):
        print("Include A Number")
        return
    elif not any(c in "!@#$%^&*" for c in pw):
        print("Include A Special Character")
        return
    else:
        print("Password valid, Thank you! ")
        return False
while True:
    password = input("Enter a Password: ")
    if password.lower() == "q":
        break
    if check_password(password) == False:
        break
# Out:
# Enter a Password:  lourdynNeilverdida
# Include A Number
# Enter a Password:  lourdynNeil
# Include A Number
# Enter a Password:  LourdyNdeil123
# Include A Special Character
# Enter a Password:  LourdynNeil123!@#
# Password valid, Thank you!

# %% [markdown]
# # Question 6

# %%
"""
Task6:  Dice Simulation (Monte Carlo). Write roll()-> int to simulate a fair die,
 then simulate 100,000 rolls to estimate the probability that the sum of two dice
 equals 7. Compare empirical result to the exact probability. Comment on random
 seeding and reproducibility. Anchor concepts: random module, simulation, averages.
 Reference: :contentReference[oaicite:12]index=12

 ChatgptPrompt: Dice Simulation (Monte Carlo). Write roll()-> int to simulate a fair die, 
 then simulate 100,000 rolls to estimate the probability that the sum of two dice equals 7
 .explain this question to me

 ChatGpt Answer: 
 Good question — let’s break it down clearly 👇

---

### 🎯 **Goal of the question**

You’re being asked to **simulate dice rolls** to estimate (not calculate exactly) the **probability** that the **sum of two dice equals 7**.
This kind of experiment is called a **Monte Carlo simulation**, which means using random sampling to approximate a probability or value.

---

### 🧠 **Concept explained**

#### Step 1: Simulate a single die roll

A die has 6 sides numbered 1–6.
You can simulate this in Python with:

```python
import random

def roll():
    return random.randint(1, 6)
```

This returns a random integer from 1 to 6, just like rolling a real die.

---

#### Step 2: Simulate two dice and check if the sum equals 7

```python
die1 = roll()
die2 = roll()
total = die1 + die2
if total == 7:
    # it’s a success
```

---

#### Step 3: Repeat this many times (e.g., 100,000 rolls)

You’ll repeat the experiment **100,000 times** to estimate how often the sum is 7.
This uses the **Monte Carlo** approach — doing many random trials to get a statistical estimate.

---

#### Step 4: Compute the probability

You count how many times the sum equals 7, then divide by the total rolls:

```python
probability = count_of_sevens / total_rolls
```

---

### ✅ **Full example code**

```python
import random

def roll() -> int:
    return random.randint(1, 6)

count = 0
trials = 100_000

for _ in range(trials):
    if roll() + roll() == 7:
        count += 1

probability = count / trials
print(f"Estimated Probability: {probability:.4f}")
```

---

### 🧮 **Expected result**

The theoretical probability of rolling a 7 with two fair dice is **6/36 = 1/6 ≈ 0.1667**.
After 100,000 simulations, your estimate should be **close to 0.1667** (around 16.7%).

---

### 🧩 **Key ideas**

* `random.randint(1, 6)` simulates one die roll.
* Running it 100,000 times makes the result statistically accurate.
* This demonstrates how **Monte Carlo simulation** uses random trials to approximate probabilities when exact computation might be hard (though in this case, we know the exact value).

---

Would you like me to show a version that also **plots the distribution** of the sums (like a histogram of all outcomes)? It’s a great visual for understanding Monte Carlo results.

Critique
Correctness: The explanation clearly defines what a Monte Carlo simulation is and correctly models the problem of finding the probability that the sum of two dice equals 7. 
The logic of rolling two dice, checking the total, and repeating the experiment many times matches the expected algorithm.
Complexity: The code runs efficiently in O(n) time, where n is the number of trials (100,000), with constant space ideal for simulation tasks.
Robustness: The program is reliable and handles randomness correctly using random.randint(). It could be improved by letting the user set the number of trials for flexibility.
Readability: The explanation and code are clear, with proper comments, indentation, and meaningful variable names. Adding a docstring for the roll() function could improve clarity.
Faithfulness: The example follows the randomization techniques from Python Programming 4, showing a proper use of probability simulation.
Improved COde:

"""
import random
def roll():
    res = random.randint(1,6)
    return res
count = 0
for r in range(10000):
    if roll() + roll() == 7:
        count += 1
print(f"The Probability is {(count/10000):.2%}")

"""
Discussion:
The empirical result from the dice simulation should be close to the exact probability of rolling a sum of 7, which is 1/6 (≈ 0.1667). 
Since the simulation uses random numbers, the result won’t match exactly, but as the number of trials increases, the average outcome 
converges toward the theoretical value a core idea of Monte Carlo methods.
"""
# Out:
# The Probability is 16.54%

# %% [markdown]
# # Question 7

# %%
"""
Tas OOP: Vehicles with Odometer and Fuel. Design classes Vehicle (base),
 Car and Truck (children). Each has color, mileage, and fuel_liters. Provide
 drive(km, km_per_liter) which increments mileage and decreases fuel (never be
low 0) and refuel(liters). Show how inheritance avoids duplication and add
 a method override in Truck (e.g., different efficiency). Include a minimal test
 script. Anchor concepts: classes vs. instances, attributes, instance methods, in
heritance/override. Reference: :contentReference[oaicite:13]index=13
Chatgpt Prompt:
Design classes Vehicle (base), Car and Truck (children). Each has color, mileage, and fuel_liters. 
Provide drive(km, km_per_liter) which increments mileage and decreases fuel (never be low 0) and refuel(liters). 
explain the question to me
Chatgpt Answer: Okay, Lourdyn — here’s what that question is asking for 👇

---

### 💡 **Goal**

You’re being asked to design a **class hierarchy** in Python that models vehicles.
That means:

* There’s one **base class** called `Vehicle`.
* Two **child (derived) classes** called `Car` and `Truck` that inherit from it.

---

### 🚗 **Shared features (for all vehicles)**

Each vehicle should have:

* `color`
* `mileage`
* `fuel_liters`

So the **base class (`Vehicle`)** will hold these common attributes.

---

### ⚙️ **Methods to create**

1. **`drive(km, km_per_liter)`**

   * Increases `mileage` by the given kilometers.
   * Decreases `fuel_liters` based on how much fuel is used:
     [
     \text{fuel used} = \frac{\text{km}}{\text{km_per_liter}}
     ]
   * But fuel should **never go below 0**.
     So if the car doesn’t have enough fuel for that trip, it should drive only until fuel runs out.

2. **`refuel(liters)`**

   * Adds fuel to the tank (increases `fuel_liters`).

---

### 🧩 **Child classes**

* `Car` and `Truck` both inherit from `Vehicle`.
* They can use the same `drive()` and `refuel()` methods from `Vehicle`,
  but you could extend or customize them later (for example, maybe a truck consumes more fuel).

---

### 🧠 **What it’s testing**

This question checks if you understand:

* **Class inheritance** (`class Car(Vehicle):`)
* **Encapsulation** (keeping each vehicle’s data separate)
* **Method logic** (fuel use, preventing negative values)

---

Would you like me to show you the **Python code** for this now (with an example run)?
class Vehicle:
    def __init__(self, color, mileage, fuel_liters):
        self.color = color
        self.mileage = mileage
        self.fuel_liters = fuel_liters

    def drive(self, km, km_per_liter):
        fuel_needed = km / km_per_liter

        # Check if there's enough fuel
        if fuel_needed <= self.fuel_liters:
            self.mileage += km
            self.fuel_liters -= fuel_needed
            print(f"✅ Drove {km} km.")
        else:
            # Drive only as far as the fuel allows
            possible_km = self.fuel_liters * km_per_liter
            self.mileage += possible_km
            self.fuel_liters = 0
            print(f"⚠️ Ran out of fuel after driving {possible_km:.2f} km.")

    def refuel(self, liters):
        self.fuel_liters += liters
        print(f"⛽ Refueled {liters} liters. Current fuel: {self.fuel_liters:.2f} liters.")


# --- Child Classes ---
class Car(Vehicle):
    def __init__(self, color, mileage, fuel_liters):
        super().__init__(color, mileage, fuel_liters)


class Truck(Vehicle):
    def __init__(self, color, mileage, fuel_liters):
        super().__init__(color, mileage, fuel_liters)


# --- Example Run ---
my_car = Car("Red", 5000, 20)
my_truck = Truck("Blue", 12000, 50)

print("🚗 Car Test:")
my_car.drive(100, 10)      # uses 10 liters
my_car.refuel(5)
print(f"Mileage: {my_car.mileage} km, Fuel left: {my_car.fuel_liters:.2f} liters\n")

print("🚚 Truck Test:")
my_truck.drive(600, 8)     # uses 75 liters, not enough fuel → partial drive
my_truck.refuel(30)
print(f"Mileage: {my_truck.mileage} km, Fuel left: {my_truck.fuel_liters:.2f} liters")

Critique
Correctness: The code correctly defines a base class Vehicle and two subclasses Car and Truck, which aligns with the object-oriented hierarchy explained in Lecture 6. 
Complexity: Each method runs efficiently in O(1) time since it performs only basic arithmetic and condition checks per call.
Robustness: The code is well-designed and prevents invalid fuel states. It could be improved by handling invalid numeric inputs or adding constraints.
Readability: The variable names and messages are clear, and indentation follows Python’s style conventions. However, adding docstrings to explain each method’s purpose and parameters would make it more self-documenting.
Faithfulness: The implementation is faithful to the OOP concepts taught — particularly  inheritance, encapsulation, and method overriding. It demonstrates how child classes reuse 
base functionality, exactly as described in the lesson’s “Parent vs Child Classes” and “Extending Functionality” sections LECTURE_6


Improved Code: 
"""
class Vehicle:
    def __init__(self, color, mileage, fuel_liters):
        self.color = color
        self.mileage = mileage
        self.fuel_liters = fuel_liters
    def drive(self, km, km_per_liter):
        fuel_needed = km / km_per_liter
        if fuel_needed <= self.fuel_liters:
            self.mileage += km
            self.fuel_liters -= fuel_needed
            print(f"Drove {km} km.")
        else:
            possible_km = self.fuel_liters * km_per_liter
            self.mileage += possible_km
            self.fuel_liters = 0
            print(f"Ran out of fuel after {possible_km:.2f} km.")
    def refuel(self, liters):
        self.fuel_liters += liters
        print(f"Refueled {liters} liters. Current fuel: {self.fuel_liters:.2f} liters.")
class Car(Vehicle):
    pass
class Truck(Vehicle):
    pass
print("Car Details")
car_color = input("Enter the color of your car: ")
car_mileage = float(input("Enter the mileage (km) of your car: "))
car_fuel = float(input("Enter the current fuel (liters) of your car: "))
car = Car(car_color, car_mileage, car_fuel)
print("Truck Details")
truck_color = input("Enter the color of your truck: ")
truck_mileage = float(input("Enter the mileage (km) of your truck: "))
truck_fuel = float(input("Enter the current fuel (liters) of your truck: "))
truck = Truck(truck_color, truck_mileage, truck_fuel)
car.drive(100, 10)
car.refuel(5)
print(f"Car Mileage: {car.mileage} km | Fuel left: {car.fuel_liters:.2f} L")
truck.drive(500, 8)
truck.refuel(20)
print(f"Truck Mileage: {truck.mileage} km | Fuel left: {truck.fuel_liters:.2f} L")
"""
Discussion:
Inheritance keeps code short and clean by letting child classes reuse what the parent already has. 
For example, the base Vehicle class can store shared details like color, mileage, and fuel_liters. 
This means Car and Truck don’t need to rewrite the same code they simply inherit it. If Truck needs 
a special rule, like being less fuel-efficient, it can override the efficiency() method to change that 
one behavior without affecting Car.
Reference: LECTURE_6
"""
# Out:
# Car Details

# %% [markdown]
# # Question 8

# %%
"""
Task8: OOP+Composition: Kennel with Dogs. Using a Dog class (name, age, breed,
 bark()), implement a Kennel manager that holds multiple Dog instances, supports
 add_dog, remove_dog, oldest_dog(), and find_by_breed(breed). Compare com
position vs. inheritance for this scenario. Anchor concepts: OOP design, managing
 collections of objects. Reference: :contentReference[oaicite:14]index=14

Chatgpt Prompt: Using a Dog class (name, age, breed, bark()), implement a Kennel manager 
that holds multiple Dog instances, supports add_dog, remove_dog, oldest_dog(), and 
find_by_breed(breed).

Chatgpt Answer: Perfect question, Lourdyn 🐶 — this is a classic OOP problem that builds on what you’ve already learned about **classes, objects, and collections** in Python.

Let’s go step by step 👇

---

### 💡 **Goal**

You’ll create two classes:

1. **`Dog`** – represents a single dog with details and a `bark()` method.
2. **`Kennel`** – manages multiple dogs and provides functions to:

   * `add_dog()`
   * `remove_dog()`
   * `oldest_dog()`
   * `find_by_breed()`

---

### 🐕 **Code Implementation**

```python
# Dog class
class Dog:
    def __init__(self, name, age, breed):
        self.name = name
        self.age = age
        self.breed = breed

    def bark(self):
        print(f"{self.name} says: Woof! 🐾")

# Kennel manager class
class Kennel:
    def __init__(self):
        self.dogs = []   # list to hold multiple Dog objects

    def add_dog(self, dog):
        self.dogs.append(dog)
        print(f"{dog.name} has been added to the kennel.")

    def remove_dog(self, name):
        for dog in self.dogs:
            if dog.name.lower() == name.lower():
                self.dogs.remove(dog)
                print(f"{name} has been removed from the kennel.")
                return
        print(f"No dog named {name} found.")

    def oldest_dog(self):
        if not self.dogs:
            print("No dogs in the kennel.")
            return None
        oldest = max(self.dogs, key=lambda d: d.age)
        print(f"The oldest dog is {oldest.name}, age {oldest.age}, breed {oldest.breed}.")
        return oldest

    def find_by_breed(self, breed):
        found = [d for d in self.dogs if d.breed.lower() == breed.lower()]
        if not found:
            print(f"No dogs of breed '{breed}' found.")
        else:
            print(f"Dogs of breed '{breed}':")
            for d in found:
                print(f" - {d.name}, age {d.age}")

# --- Example Usage ---
kennel = Kennel()

# Add dogs
dog1 = Dog("Buddy", 3, "Labrador")
dog2 = Dog("Charlie", 5, "Beagle")
dog3 = Dog("Max", 2, "Labrador")

kennel.add_dog(dog1)
kennel.add_dog(dog2)
kennel.add_dog(dog3)

# Dogs bark
dog1.bark()
dog2.bark()

# Find and remove
kennel.find_by_breed("Labrador")
kennel.oldest_dog()
kennel.remove_dog("Charlie")
kennel.oldest_dog()
```

---

### 🧠 **Explanation**

* The **`Dog` class** stores each dog’s details and has a simple `bark()` action.
* The **`Kennel` class** keeps a list of dogs and provides operations to:

  * **Add** or **remove** dogs from the list.
  * Find the **oldest** dog using `max()` with a `lambda` function.
  * **Search** for all dogs of a certain breed.

---

### 🧪 **Sample Output**

```
Buddy has been added to the kennel.
Charlie has been added to the kennel.
Max has been added to the kennel.
Buddy says: Woof! 🐾
Charlie says: Woof! 🐾
Dogs of breed 'Labrador':
 - Buddy, age 3
 - Max, age 2
The oldest dog is Charlie, age 5, breed Beagle.
Charlie has been removed from the kennel.
The oldest dog is Buddy, age 3, breed Labrador.
```

---

Would you like me to make a version where the user can **input dog details** (name, age, breed) instead of hardcoding them?

critique:
Correctness:
The code correctly uses inheritance and method overriding to represent Vehicle, Car, and Truck. 
The drive() and refuel() methods update mileage and fuel accurately while ensuring fuel doesn’t go below zero. However, 
it lacks user input for interactivity and doesn’t validate cases like negative distances or over-refueling.
Time and Space Complexity:
Both are O(1) since calculations and updates happen instantly, regardless of input size.
Robustness:
The program works well with preset data but could be improved with input prompts and validation. 
Adding error handling would prevent invalid or unrealistic values.
Readability:
The structure is clean, with clear class names, consistent formatting, and descriptive print messages. 
The use of super() shows good understanding of inheritance. Including docstrings for each method would improve clarity.
Faithfulness:
It follows key lessons on Function Creation (Lesson 3), Conditionals (Lesson 4), and OOP(Lesson 6). 

Improved Code:

"""

class Dog:
    def __init__(self, name, age, breed):
        self.name = name
        self.age = age
        self.breed = breed
    def bark(self):
        print(f"{self.name} says: Woof!")
class Kennel:
    def __init__(self):
        self.dogs = []
    def add_dog(self, dog):
        self.dogs.append(dog)
        print(f"✅ {dog.name} has been added to the kennel.")
    def remove_dog(self, name):
        for dog in self.dogs:
            if dog.name.lower() == name.lower():
                self.dogs.remove(dog)
                print(f"{name} has been removed from the kennel.")
                return
        print(f" No dog named '{name}' found.")
    def oldest_dog(self):
        if not self.dogs:
            print("No dogs in the kennel.")
            return None
        oldest = max(self.dogs, key=lambda d: d.age)
        print(f"The oldest dog is {oldest.name}, age {oldest.age}, breed {oldest.breed}.")
        return oldest
    def find_by_breed(self, breed):
        found = [d for d in self.dogs if d.breed.lower() == breed.lower()]
        if not found:
            print(f"No dogs of breed '{breed}' found.")
        else:
            print(f"Dogs of breed '{breed}':")
            for d in found:
                print(f" - {d.name}, age {d.age}")
kennel = Kennel()
while True:
    print("\n=== Kennel Manager ===")
    print("1. Add Dog")
    print("2. Remove Dog")
    print("3. Find Oldest Dog")
    print("4. Find by Breed")
    print("5. Show All Dogs")
    print("6. Exit")
    choice = input("Enter your choice (1-6): ")
    if choice == "1":
        name = input("Enter dog's name: ")
        age = int(input("Enter dog's age: "))
        breed = input("Enter dog's breed: ")
        new_dog = Dog(name, age, breed)
        kennel.add_dog(new_dog)
        new_dog.bark()
    elif choice == "2":
        name = input("Enter the name of the dog to remove: ")
        kennel.remove_dog(name)
    elif choice == "3":
        kennel.oldest_dog()
    elif choice == "4":
        breed = input("Enter breed to search: ")
        kennel.find_by_breed(breed)
    elif choice == "5":
        if not kennel.dogs:
            print("No dogs in the kennel yet.")
        else:
            print("Current Dogs in the Kennel:")
            for d in kennel.dogs:
                print(f" - {d.name}, age {d.age}, breed {d.breed}")
    elif choice == "6":
        print("Exiting Kennel Manager. Goodbye!")
        break
    else:
        print("Invalid choice. Please enter a number from 1 to 6.")
"""
Discussion:
In this program, composition is used instead of inheritance because the DogManager class 
contains Dog objects rather than being a Dog. This design makes sense since the manager’s
role is to organize and manage multiple dogs, not to behave like one. If inheritance were
used, it would create an illogical relationship—since a manager is not a type of dog. Using 
composition keeps the two classes separate and reusable: Dog handles its own behavior such
as barking, while DogManager focuses on managing a group of dogs without duplicating code
or forcing an unnatural parent-child structure.
"""

# %% [markdown]
# # Question 9

# %%
"""
Task 9: Modules and Packages: Helpers. Create a package helpers/ with modules
 string_utils.py (function shout(s) uppercases) and math_utils.py (function area(l,w)).
 Then a main.py that imports with both import ... as ... and from ...
 import .... Explain namespace collisions and why aliases help. Anchor con
cepts: modules, packages, import variations, namespaces. Reference: :contentRe
ference[oaicite:15]index=15

Chatgpt Prompt: Can you make a Python package called helpers that has two modules 
one named string_utils.py with a function shout(s) that returns the string in uppercase,
and another called math_utils.py with a function area(l, w) that returns the product of 
the two numbers? Then, create a main.py file that imports both modules.

Chatgpt Answer: Here’s the simple working version for your request 👇

---

### 📁 Folder structure

```
helpers/
    __init__.py
    string_utils.py
    math_utils.py
main.py
```

---

### 🧩 helpers/string_utils.py

```python
def shout(s):
    return s.upper()
```

---

### 🧮 helpers/math_utils.py

```python
def area(l, w):
    return l * w
```

---

### 💻 main.py

```python
# Import using alias
import helpers.string_utils as su
import helpers.math_utils as mu

# Import specific functions
from helpers.string_utils import shout
from helpers.math_utils import area

# Using aliases
print(su.shout("hello world"))
print(f"Area using alias: {mu.area(5, 10)}")

# Using direct imports
print(shout("python modules"))
print(f"Area using direct import: {area(7, 3)}")
```

---

### 🧠 Explanation (namespace & aliases)

When you import multiple modules, different files can define functions with **the same name**, such as `area()` in both `math_utils.py` and `geometry.py`.
This can cause **namespace collisions** — meaning Python can’t tell which `area()` you meant.

By using **aliases** (like `mu.area` and `su.shout`), each function stays inside its module’s own **namespace**, preventing conflicts and making your code clearer.

✅ `helpers.math_utils.area()` → refers only to the math module
✅ `helpers.string_utils.shout()` → refers only to the string module

Critique
Correctness: The code correctly defines a package with two modules. The functions shout() and area() behave as expected, returning uppercase 
text and computing area accurately.
Complexity: All operations run in O(1) time since they perform single string or arithmetic operations, which are constant-time tasks.
Robustness: Works well for typical inputs but lacks validation; adding checks for numeric types in area() or
non-empty strings in shout() could improve reliability.
Readability: The structure is clean and simple, following standard folder and module organization.
Variable names and import statements are clear, making the code easy to understand for me.
Faithfulness: It follows the lesson on Modules and Packages, clearly showing how namespaces and aliases 
prevent function name conflicts and improve modular programming. Reference: Lesson 7 — Modules, Packages.

Improved Code: 
"""
import Helpers.string_utils as str_help
import Helpers.math_utils as math_help
from Helpers.string_utils import shout
from Helpers.math_utils import area
text = input("Enter a word or sentence: ")
str_help.shout(text)
length = float(input("Enter the length: "))
width = float(input("Enter the width: "))
print(f"Area : {math_help.area(length, width)}")
# Out:
# Enter a word or sentence:  Lourdyn
# LOURDYN
# Enter the length:  3
# Enter the width:  42
# Area : 126.0

# %% [markdown]
# # Question 10

# %%
"""
Task 10: . Robust Temperature Converter (Functions + Exceptions). Write two func
tions: cel_to_far(c) and far_to_cel(f) with type hints and docstrings. Build a
 CLI that asks the user which direction to convert and validates input (gracefully
 handles bad entries). Include unit tests (doctest or simple asserts) covering typical
 3 and edge cases (e.g.,-40). Anchor concepts: writing functions, control flow, input
 handling, testing.

 Chatgpt Prompt: Can you make a Python program that converts temperatures between Celsius 
 and Fahrenheit? It should have two functions — cel_to_far(c) and far_to_cel(f) — both with 
 type hints and docstrings. Then, create a simple program that asks the user which direction 
 they want to convert and handles invalid input gracefully using exceptions.

 Chatgpt Answer: Of course, Lourdyn 👍 Here’s a **simple, clear, and robust** version of your temperature converter — following the same format and style as your lecture notes (functions, exceptions, and input handling).

---

### 🌡️ **Code**

```python
def cel_to_far(c: float) -> float:
  
    Converts Celsius to Fahrenheit.
    Formula: (°C × 9/5) + 32
   
    return (c * 9 / 5) + 32


def far_to_cel(f: float) -> float:
  
    Converts Fahrenheit to Celsius.
    Formula: (°F − 32) × 5/9
  
    return (f - 32) * 5 / 9


# --- Main Program ---
print("🌡️ Temperature Converter 🌡️")

while True:
    try:
        choice = input("Convert (1) Celsius to Fahrenheit or (2) Fahrenheit to Celsius? (Q to quit): ")

        if choice.lower() == "q":
            print("Exiting program. Goodbye!")
            break

        if choice == "1":
            c = float(input("Enter temperature in Celsius: "))
            print(f"{c}°C = {cel_to_far(c):.2f}°F")

        elif choice == "2":
            f = float(input("Enter temperature in Fahrenheit: "))
            print(f"{f}°F = {far_to_cel(f):.2f}°C")

        else:
            print("❌ Invalid choice. Please enter 1, 2, or Q.")

    except ValueError:
        print("⚠️ Please enter a valid number for temperature.")
```

---

### 🧠 **Explanation**

* The program defines two clear functions with **type hints** and **docstrings**.
* It uses a `while True` loop to keep running until the user quits with **Q**.
* Input validation and errors like entering text instead of a number are handled with a `try-except` block.
* Results are formatted neatly to **2 decimal places**.

---

### 🧪 **Example Run**

```
🌡️ Temperature Converter 🌡️
Convert (1) Celsius to Fahrenheit or (2) Fahrenheit to Celsius? (Q to quit): 1
Enter temperature in Celsius: 37
37.0°C = 98.60°F

Convert (1) Celsius to Fahrenheit or (2) Fahrenheit to Celsius? (Q to quit): 2
Enter temperature in Fahrenheit: 212
212.0°F = 100.00°C

Convert (1) Celsius to Fahrenheit or (2) Fahrenheit to Celsius? (Q to quit): q
Exiting program. Goodbye!
```

---

✅ **Result:**
A clean, easy-to-understand, user-friendly temperature converter that gracefully handles errors and invalid inputs.

Critique
Correctness: The program correctly converts between Celsius and Fahrenheit using accurate formulas and proper input validation. The conversion logic and rounding to two decimal places match the mathematical expectation.
Complexity: Both conversion functions run in O(1) time and space since they perform only arithmetic operations and a few comparisons.
Robustness: The code safely handles invalid entries using try-except and provides clear user feedback. It could be slightly improved by adding range checks for extreme values or optional retries for invalid input.
Readability: The structure is clear and follows the lesson’s format. Type hints, meaningful variable names, and consistent formatting make it easy to read. Adding short docstrings above the functions would complete the style.
Faithfulness: The solution follows lessons on Functions, Input, and Exception Handling, showing proper use of loops, error catching, and formatted printing — consistent with Lesson 3: Functions and Loops and Lesson 4: Conditionals and Input Validation.

Improved Code: 

"""
def cel_to_far(c: float) -> float:
    return (c * 1.8) + 32
def far_to_cel(f: float) -> float:
    return (f - 32) * 1.8
while True:
    print("\n1. Celsius to Fahrenheit")
    print("2. Fahrenheit to Celsius")
    print("Q. Quit")
    choice = input("Choose conversion: ")
    if choice.lower() == "q":
        print("Program ended.")
        break
    try:
        if choice == "1":
            c = float(input("Enter temperature in Celsius: "))
            result = cel_to_far(c)
            print(f"{c}°C = {result:.2f}°F")
        elif choice == "2":
            f = float(input("Enter temperature in Fahrenheit: "))
            result = far_to_cel(f)
            print(f"{f}°F = {result:.2f}°C")
        else:
            print("Invalid choice. Please select 1, 2, or Q.")
    except ValueError:
        print("Invalid input. Please enter a numeric value.")
"""
Discussion:
You can improve the Temperature Converter program by adding unit tests to ensure both conversion functions work correctly 
especially for typical and edge cases like -40, where Celsius and Fahrenheit values are the same. These assertions act like 
automatic checks that verify correctness without needing user input.You can also replace assert with doctests in the docstrings, 
allowing automated testing directly.
"""
# Out:
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# Q. Quit
# Choose conversion:  1
# Enter temperature in Celsius:  1.42
# 1.42°C = 34.56°F
#
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# Q. Quit
# Choose conversion:  q
# Program ended.
